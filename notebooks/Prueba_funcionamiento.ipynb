# %%
from epToolbox import *
import numpy as np
import json

# %%
mat,mats = importMaterials("../osm/edificio_este.osm")

# %%
mats
# Out:
# {'concreto_fc150_granzon_L8_a0pX': {'Handle': '{2e7157dc-32c2-44e3-9415-7874ececbba9}',
#   'Name': 'concreto_fc150_granzon_L8_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': 0.8,
#   'Solar Absorptance': 0.3,
#   'Visible Absorptance': 0.3},
#  'concreto_fc150_L6_a0pX': {'Handle': '{acc9b317-088e-4fa3-a849-9aec59e11271}',
#   'Name': 'concreto_fc150_L6_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': '',
#   'Solar Absorptance': 0.5,
#   'Visible Absorptance': 0.5},
#  'concreto_fc250_L30_a0pX': {'Handle': '{fe21d530-02b9-4f7e-8369-6955e97efd5a}',
#   'Name': 'concreto_fc250_L30_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.3,
#   'Conductivity {W/m-K}': 1.3,
# ...

# %%
mats["concreto_fc150_granzon_L8_a0pX"]['Conductivity {W/m-K}']
# Out:
# 1.3

# %% [markdown]
# # Guarda y abre dictionario guardado con numpy

# %%
np.save("materiales.dict",mats)

# %%
read_dictionary = np.load('materiales.dict.npy',allow_pickle='TRUE').item()
read_dictionary
# Out:
# {'concreto_fc150_granzon_L8_a0pX': {'Handle': '{2e7157dc-32c2-44e3-9415-7874ececbba9}',
#   'Name': 'concreto_fc150_granzon_L8_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': 0.8,
#   'Solar Absorptance': 0.3,
#   'Visible Absorptance': 0.3},
#  'concreto_fc150_L6_a0pX': {'Handle': '{acc9b317-088e-4fa3-a849-9aec59e11271}',
#   'Name': 'concreto_fc150_L6_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': '',
#   'Solar Absorptance': 0.5,
#   'Visible Absorptance': 0.5},
#  'concreto_fc250_L30_a0pX': {'Handle': '{fe21d530-02b9-4f7e-8369-6955e97efd5a}',
#   'Name': 'concreto_fc250_L30_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.3,
#   'Conductivity {W/m-K}': 1.3,
# ...

# %%
read_dictionary['concreto_fc150_granzon_L8_a0pX']["Roughness"]
# Out:
# 'MediumRough'

# %% [markdown]
# # Guarda y abre dictionario con json

# %%
archivo = open("materiales.json", "w")
json.dump(mats,archivo)
archivo.close()

# %%
with open('materiales.json') as json_file:
    diccionario = json.load(json_file)

# %%
diccionario['concreto_fc150_granzon_L8_a0pX']["Roughness"]
# Out:
# 'MediumRough'

# %%
diccionario
# Out:
# {'concreto_fc150_granzon_L8_a0pX': {'Handle': '{2e7157dc-32c2-44e3-9415-7874ececbba9}',
#   'Name': 'concreto_fc150_granzon_L8_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': 0.8,
#   'Solar Absorptance': 0.3,
#   'Visible Absorptance': 0.3},
#  'concreto_fc150_L6_a0pX': {'Handle': '{acc9b317-088e-4fa3-a849-9aec59e11271}',
#   'Name': 'concreto_fc150_L6_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.15,
#   'Conductivity {W/m-K}': 1.3,
#   'Density {kg/m3}': 1800,
#   'Specific Heat {J/kg-K}': 1000,
#   'Thermal Absorptance': '',
#   'Solar Absorptance': 0.5,
#   'Visible Absorptance': 0.5},
#  'concreto_fc250_L30_a0pX': {'Handle': '{fe21d530-02b9-4f7e-8369-6955e97efd5a}',
#   'Name': 'concreto_fc250_L30_a0pX',
#   'Roughness': 'MediumRough',
#   'Thickness {m}': 0.3,
#   'Conductivity {W/m-K}': 1.3,
# ...
